# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

plt.style.use("dark_background")

# %%
df = pd.read_csv("train_history.csv", index_col=0)
df.head()
# Out:
#    round  worker  train/loss  epoch                        time
# 0      0       0    2.289792      0  2023-08-06 23:29:08.624666
# 1      0       0    2.264599      1  2023-08-06 23:29:09.673988
# 2      0       1    2.289511      0  2023-08-06 23:29:10.735234
# 3      0       1    2.264229      1  2023-08-06 23:29:11.788282
# 4      0       2    2.289017      0  2023-08-06 23:29:12.853363

# %%
sns.lineplot(data=df, x="round", y="train/loss")
plt.grid(linestyle=":")
plt.show()
