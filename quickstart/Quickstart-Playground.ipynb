# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

plt.style.use("ggplot")

# %%
df = pd.read_feather("out/demo_history.feather")
df.head()
# Out:
#    train/loss  train/epoch  train/batch_idx                 train/time  \
# 0    2.286742            0                0 2023-09-13 11:38:40.726857
# 1    2.300195            0                1 2023-09-13 11:38:40.733247
# 2    2.303393            0                2 2023-09-13 11:38:40.740177
# 3    2.274529            0                3 2023-09-13 11:38:40.747272
# 4    2.275694            0                4 2023-09-13 11:38:40.753943
#
#    node/idx node/kind  parent/idx parent/kind  round  strategy
# 0         8    worker           3  aggregator      0  fed-prox
# 1         8    worker           3  aggregator      0  fed-prox
# 2         8    worker           3  aggregator      0  fed-prox
# 3         8    worker           3  aggregator      0  fed-prox
# 4         8    worker           3  aggregator      0  fed-prox

# %%
sns.lineplot(df, x="round", y="train/loss")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
